# %%
cd /content/drive/MyDrive/HybridRE/
# Out:
# /content/drive/MyDrive/HybridRE

# %% [markdown]
# # Predictions

# %% [markdown]
# ### I - TACRED

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "bert-base-cased" --check_model "./PLM_Models/Bert-Base_TACRED/BERT-BASE_TACRED.bin" --test_path ./Data/0_RAW/TACRED/test.json  --predictions_path ./Data/1_Processed/TACRED/PLM_BERT-BASE_TACRED_TEST.csv  --dataset_type TACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# config.json: 100% 570/570 [00:00<00:00, 3.85MB/s]
# tokenizer_config.json: 100% 49.0/49.0 [00:00<00:00, 407kB/s]
# vocab.txt: 100% 213k/213k [00:00<00:00, 516kB/s]
# tokenizer.json: 100% 436k/436k [00:00<00:00, 932kB/s]
# 2025-12-19 15:17:24.417784: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-19 15:17:24.435048: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "bert-base-cased" --check_model "./PLM_Models/Bert-Base_TACRED/BERT-BASE_TACRED.bin" --test_path ./Data/0_RAW/TACRED/dev.json  --predictions_path ./Data/1_Processed/TACRED/PLM_BERT-BASE_TACRED_DEV.csv  --dataset_type TACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# 2025-12-19 15:18:30.020409: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-19 15:18:30.038406: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "bert-large-cased" --check_model "./PLM_Models/Bert-Large_TACRED/BERT-LARGE_TACRED.bin" --test_path ./Data/0_RAW/TACRED/test.json  --predictions_path ./Data/1_Processed/TACRED/PLM_BERT-LARGE_TACRED_TEST.csv  --dataset_type TACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# config.json: 100% 762/762 [00:00<00:00, 5.49MB/s]
# tokenizer_config.json: 100% 49.0/49.0 [00:00<00:00, 385kB/s]
# vocab.txt: 100% 213k/213k [00:00<00:00, 33.9MB/s]
# tokenizer.json: 100% 436k/436k [00:00<00:00, 1.03MB/s]
# 2025-12-19 15:19:32.333605: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "bert-large-cased" --check_model "./PLM_Models/Bert-Large_TACRED/BERT-LARGE_TACRED.bin" --test_path ./Data/0_RAW/TACRED/dev.json  --predictions_path ./Data/1_Processed/TACRED/PLM_BERT-LARGE_TACRED_DEV.csv  --dataset_type TACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# 2025-12-19 15:21:03.937204: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-19 15:21:03.954466: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "roberta-base" --check_model "./PLM_Models/RoBERTa-Base_TACRED/RoBERTa-BASE_TACRED.bin" --test_path ./Data/0_RAW/TACRED/test.json  --predictions_path ./Data/1_Processed/TACRED/PLM_ROBERTA-BASE_TACRED_TEST.csv  --dataset_type TACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# config.json: 100% 481/481 [00:00<00:00, 3.03MB/s]
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 195kB/s]
# vocab.json: 100% 899k/899k [00:00<00:00, 2.10MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 2.07MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 2.02MB/s]
# 2025-12-19 15:22:16.217060: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "roberta-base" --check_model "./PLM_Models/RoBERTa-Base_TACRED/RoBERTa-BASE_TACRED.bin" --test_path ./Data/0_RAW/TACRED/dev.json  --predictions_path ./Data/1_Processed/TACRED/PLM_ROBERTA-BASE_TACRED_DEV.csv  --dataset_type TACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# 2025-12-19 15:23:18.884685: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-19 15:23:18.900652: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "roberta-large" --check_model "./PLM_Models/RoBERTa-Large_TACRED/RoBERTa-LARGE_TACRED.bin" --test_path ./Data/0_RAW/TACRED/test.json  --predictions_path ./Data/1_Processed/TACRED/PLM_ROBERTA-LARGE_TACRED_TEST.csv  --dataset_type TACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# config.json: 100% 482/482 [00:00<00:00, 3.04MB/s]
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 161kB/s]
# vocab.json: 100% 899k/899k [00:00<00:00, 2.11MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 1.05MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 2.10MB/s]
# 2025-12-19 15:24:23.354159: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "roberta-large" --check_model "./PLM_Models/RoBERTa-Large_TACRED/RoBERTa-LARGE_TACRED.bin" --test_path ./Data/0_RAW/TACRED/dev.json  --predictions_path ./Data/1_Processed/TACRED/PLM_ROBERTA-LARGE_TACRED_DEV.csv  --dataset_type TACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# 2025-12-19 15:25:55.871407: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-19 15:25:55.887651: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "SpanBERT/spanbert-large-cased" --check_model "./PLM_Models/Spanbert-Large_TACRED/SpanBERT_Large_TACRED.bin" --test_path ./Data/0_RAW/TACRED/test.json  --predictions_path ./Data/1_Processed/TACRED/PLM_SpanBERT-LARGE_TACRED_TEST.csv  --dataset_type TACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# config.json: 100% 414/414 [00:00<00:00, 3.82MB/s]
# vocab.txt: 213kB [00:00, 50.6MB/s]
# 2026-01-16 00:45:27.390720: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768524327.409751    5141 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "SpanBERT/spanbert-large-cased" --check_model "./PLM_Models/Spanbert-Large_TACRED/SpanBERT_Large_TACRED.bin" --test_path ./Data/0_RAW/TACRED/dev.json  --predictions_path ./Data/1_Processed/TACRED/PLM_SpanBERT-LARGE_TACRED_DEV.csv  --dataset_type TACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# 2026-01-16 00:48:00.780688: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768524480.800281    5889 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768524480.806185    5889 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "microsoft/deberta-v3-large" --check_model "./PLM_Models/Deberta-Large_TACRED/Deberta_Large_TACRED.bin" --test_path ./Data/0_RAW/TACRED/test.json  --predictions_path ./Data/1_Processed/TACRED/PLM_DEBERTA-LARGE_TACRED_TEST.csv  --dataset_type TACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# config.json: 100% 580/580 [00:00<00:00, 5.22MB/s]
# tokenizer_config.json: 100% 52.0/52.0 [00:00<00:00, 404kB/s]
# spm.model: 100% 2.46M/2.46M [00:01<00:00, 1.99MB/s]
# /usr/local/lib/python3.12/dist-packages/transformers/convert_slow_tokenizer.py:566: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "microsoft/deberta-v3-large" --check_model "./PLM_Models/Deberta-Large_TACRED/Deberta_Large_TACRED.bin" --test_path ./Data/0_RAW/TACRED/dev.json  --predictions_path ./Data/1_Processed/TACRED/PLM_DEBERTA-LARGE_TACRED_DEV.csv  --dataset_type TACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# /usr/local/lib/python3.12/dist-packages/transformers/convert_slow_tokenizer.py:566: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# 2026-01-16 00:53:56.533558: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %% [markdown]
# ### II - TACREV

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "bert-base-cased" --check_model "./PLM_Models/Bert-Base_TACRED/BERT-BASE_TACRED.bin" --test_path ./Data/0_RAW/TACREV/test.json  --predictions_path ./Data/1_Processed/TACREV/PLM_BERT-BASE_TACREV_TEST.csv  --dataset_type TACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# 2025-12-19 15:27:05.921280: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-19 15:27:05.940201: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "bert-base-cased" --check_model "./PLM_Models/Bert-Base_TACRED/BERT-BASE_TACRED.bin" --test_path ./Data/0_RAW/TACREV/dev.json  --predictions_path ./Data/1_Processed/TACREV/PLM_BERT-BASE_TACREV_DEV.csv  --dataset_type TACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# 2025-12-19 15:27:50.940891: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-19 15:27:50.958244: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "bert-large-cased" --check_model "./PLM_Models/Bert-Large_TACRED/BERT-LARGE_TACRED.bin" --test_path ./Data/0_RAW/TACREV/test.json  --predictions_path ./Data/1_Processed/TACREV/PLM_BERT-LARGE_TACREV_TEST.csv  --dataset_type TACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# 2025-12-19 15:28:51.271818: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-19 15:28:51.289649: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "bert-large-cased" --check_model "./PLM_Models/Bert-Large_TACRED/BERT-LARGE_TACRED.bin" --test_path ./Data/0_RAW/TACREV/dev.json  --predictions_path ./Data/1_Processed/TACREV/PLM_BERT-LARGE_TACREV_DEV.csv  --dataset_type TACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# 2025-12-19 15:29:43.051453: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-19 15:29:43.069115: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "roberta-base" --check_model "./PLM_Models/RoBERTa-Base_TACRED/RoBERTa-BASE_TACRED.bin" --test_path ./Data/0_RAW/TACREV/test.json  --predictions_path ./Data/1_Processed/TACREV/PLM_ROBERTA-BASE_TACREV_TEST.csv  --dataset_type TACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# 2025-12-19 15:30:50.720319: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-19 15:30:50.736614: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "roberta-base" --check_model "./PLM_Models/RoBERTa-Base_TACRED/RoBERTa-BASE_TACRED.bin" --test_path ./Data/0_RAW/TACREV/dev.json  --predictions_path ./Data/1_Processed/TACREV/PLM_ROBERTA-BASE_TACREV_DEV.csv  --dataset_type TACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# 2025-12-19 15:31:36.004074: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-19 15:31:36.021022: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "roberta-large" --check_model "./PLM_Models/RoBERTa-Large_TACRED/RoBERTa-LARGE_TACRED.bin" --test_path ./Data/0_RAW/TACREV/test.json  --predictions_path ./Data/1_Processed/TACREV/PLM_ROBERTA-LARGE_TACREV_TEST.csv  --dataset_type TACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# 2025-12-19 15:32:34.738476: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-19 15:32:34.754998: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "roberta-large" --check_model "./PLM_Models/RoBERTa-Large_TACRED/RoBERTa-LARGE_TACRED.bin" --test_path ./Data/0_RAW/TACREV/dev.json  --predictions_path ./Data/1_Processed/TACREV/PLM_ROBERTA-LARGE_TACREV_DEV.csv  --dataset_type TACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# 2025-12-19 15:33:28.773171: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-19 15:33:28.789793: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "SpanBERT/spanbert-large-cased" --check_model "./PLM_Models/Spanbert-Large_TACRED/SpanBERT_Large_TACRED.bin" --test_path ./Data/0_RAW/TACREV/test.json  --predictions_path ./Data/1_Processed/TACREV/PLM_SpanBERT-LARGE_TACREV_TEST.csv  --dataset_type TACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# 2026-01-16 00:57:29.737867: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768525049.757545    8401 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768525049.763691    8401 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "SpanBERT/spanbert-large-cased" --check_model "./PLM_Models/Spanbert-Large_TACRED/SpanBERT_Large_TACRED.bin" --test_path ./Data/0_RAW/TACREV/dev.json  --predictions_path ./Data/1_Processed/TACREV/PLM_SpanBERT-LARGE_TACREV_DEV.csv  --dataset_type TACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# 2026-01-16 00:59:40.663711: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768525180.683187    8977 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768525180.689210    8977 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "microsoft/deberta-v3-large" --check_model "./PLM_Models/Deberta-Large_TACRED/Deberta_Large_TACRED.bin" --test_path ./Data/0_RAW/TACREV/test.json  --predictions_path ./Data/1_Processed/TACREV/PLM_DEBERTA-LARGE_TACREV_TEST.csv  --dataset_type TACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# /usr/local/lib/python3.12/dist-packages/transformers/convert_slow_tokenizer.py:566: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# 2026-01-16 01:02:32.904189: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "microsoft/deberta-v3-large" --check_model "./PLM_Models/Deberta-Large_TACRED/Deberta_Large_TACRED.bin" --test_path ./Data/0_RAW/TACREV/dev.json  --predictions_path ./Data/1_Processed/TACREV/PLM_DEBERTA-LARGE_TACREV_DEV.csv  --dataset_type TACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# /usr/local/lib/python3.12/dist-packages/transformers/convert_slow_tokenizer.py:566: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# 2026-01-16 01:05:10.402198: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %% [markdown]
# ### I - ReTACRED

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "bert-base-cased" --check_model "./PLM_Models/Bert-Base_ReTACRED/BERT-BASE_ReTACRED.bin" --test_path ./Data/0_RAW/ReTACRED/test.json  --predictions_path ./Data/1_Processed/ReTACRED/PLM_BERT-BASE_ReTACRED_TEST.csv  --dataset_type RETACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# 2025-12-19 15:34:38.153415: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-19 15:34:38.172123: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "bert-base-cased" --check_model "./PLM_Models/Bert-Base_ReTACRED/BERT-BASE_ReTACRED.bin" --test_path ./Data/0_RAW/ReTACRED/dev.json  --predictions_path ./Data/1_Processed/ReTACRED/PLM_BERT-BASE_ReTACRED_DEV.csv  --dataset_type RETACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# 2026-01-07 13:29:15.113863: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767792555.133317    5663 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767792555.139338    5663 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "bert-large-cased" --check_model "./PLM_Models/Bert-Large_ReTACRED/BERT-LARGE_ReTACRED.bin" --test_path ./Data/0_RAW/ReTACRED/test.json  --predictions_path ./Data/1_Processed/ReTACRED/PLM_BERT-LARGE_ReTACRED_TEST.csv  --dataset_type RETACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# 2025-12-19 15:35:46.738575: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-19 15:35:46.755301: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "bert-large-cased" --check_model "./PLM_Models/Bert-Large_ReTACRED/BERT-LARGE_ReTACRED.bin" --test_path ./Data/0_RAW/ReTACRED/dev.json  --predictions_path ./Data/1_Processed/ReTACRED/PLM_BERT-LARGE_ReTACRED_DEV.csv  --dataset_type RETACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# config.json: 100% 762/762 [00:00<00:00, 3.88MB/s]
# tokenizer_config.json: 100% 49.0/49.0 [00:00<00:00, 309kB/s]
# vocab.txt: 100% 213k/213k [00:00<00:00, 1.76MB/s]
# tokenizer.json: 100% 436k/436k [00:00<00:00, 3.38MB/s]
# 2026-01-07 13:30:29.412577: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767792629.432615    5984 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "roberta-base" --check_model "./PLM_Models/RoBERTa-Base_ReTACRED/RoBERTa-BASE_ReTACRED.bin" --test_path ./Data/0_RAW/ReTACRED/test.json  --predictions_path ./Data/1_Processed/ReTACRED/PLM_ROBERTA-BASE_ReTACRED_TEST.csv  --dataset_type RETACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# 2025-12-19 15:37:14.441470: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-19 15:37:14.457962: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "roberta-base" --check_model "./PLM_Models/RoBERTa-Base_ReTACRED/RoBERTa-BASE_ReTACRED.bin" --test_path ./Data/0_RAW/ReTACRED/dev.json  --predictions_path ./Data/1_Processed/ReTACRED/PLM_ROBERTA-BASE_ReTACRED_DEV.csv  --dataset_type RETACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# 2026-01-07 13:24:57.815026: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767792297.832391    4551 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767792297.837519    4551 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "roberta-large" --check_model "./PLM_Models/RoBERTa-Large_ReTACRED/RoBERTa-LARGE_ReTACRED.bin" --test_path ./Data/0_RAW/ReTACRED/test.json  --predictions_path ./Data/1_Processed/ReTACRED/PLM_ROBERTA-LARGE_ReTACRED_TEST.csv  --dataset_type RETACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# 2025-12-19 15:38:17.808701: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-19 15:38:17.824335: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "roberta-large" --check_model "./PLM_Models/RoBERTa-Large_ReTACRED/RoBERTa-LARGE_ReTACRED.bin" --test_path ./Data/0_RAW/ReTACRED/dev.json  --predictions_path ./Data/1_Processed/ReTACRED/PLM_ROBERTA-LARGE_ReTACRED_DEV.csv  --dataset_type RETACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# config.json: 100% 482/482 [00:00<00:00, 3.31MB/s]
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 207kB/s]
# vocab.json: 100% 899k/899k [00:00<00:00, 6.94MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 3.73MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 7.20MB/s]
# 2026-01-07 13:26:25.485149: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "SpanBERT/spanbert-large-cased" --check_model "./PLM_Models/Spanbert-Large_ReTACRED/SpanBERT_Large_ReTACRED.bin" --test_path ./Data/0_RAW/ReTACRED/test.json  --predictions_path ./Data/1_Processed/ReTACRED/PLM_SpanBERT-LARGE_ReTACRED_TEST.csv  --dataset_type RETACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# 2026-01-16 01:08:40.295965: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768525720.315596   11230 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768525720.321549   11230 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "SpanBERT/spanbert-large-cased" --check_model "./PLM_Models/Spanbert-Large_ReTACRED/SpanBERT_Large_ReTACRED.bin" --test_path ./Data/0_RAW/ReTACRED/dev.json  --predictions_path ./Data/1_Processed/ReTACRED/PLM_SpanBERT-LARGE_ReTACRED_DEV.csv  --dataset_type RETACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# 2026-01-16 01:10:49.178964: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768525849.200202   11778 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768525849.206214   11778 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "microsoft/deberta-v3-large" --check_model "./PLM_Models/Deberta-Large_ReTACRED/Deberta_Large_ReTACRED.bin" --test_path ./Data/0_RAW/ReTACRED/test.json  --predictions_path ./Data/1_Processed/ReTACRED/PLM_DEBERTA-LARGE_ReTACRED_TEST.csv  --dataset_type RETACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# /usr/local/lib/python3.12/dist-packages/transformers/convert_slow_tokenizer.py:566: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# 2026-01-16 01:13:21.519712: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
# !python3 get_PLM_Predictions.py --model_name_or_path  "microsoft/deberta-v3-large" --check_model "./PLM_Models/Deberta-Large_ReTACRED/Deberta_Large_ReTACRED.bin" --test_path ./Data/0_RAW/ReTACRED/dev.json  --predictions_path ./Data/1_Processed/ReTACRED/PLM_DEBERTA-LARGE_ReTACRED_DEV.csv  --dataset_type RETACRED
# Out:
# /content/drive/MyDrive/HybridRE/model.py:21: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast()
# Initializing device...
# Using device: GPU
# [LOG] Loading model and tokenizer...
# /usr/local/lib/python3.12/dist-packages/transformers/convert_slow_tokenizer.py:566: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# 2026-01-16 01:15:54.208789: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...
